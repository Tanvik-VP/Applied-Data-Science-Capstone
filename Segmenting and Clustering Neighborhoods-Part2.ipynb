# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json, lxml
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
# import folium # map rendering library
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(url).text
soup = BeautifulSoup(source)

table_data = soup.find('div', class_='mw-parser-output')
table = table_data.table.tbody

columns = ['PostalCode', 'Borough', 'Neighbourhood']
data = dict({key:[]*len(columns) for key in columns})

for row in table.find_all('tr'):
    for i,column in zip(row.find_all('td'),columns):
        i = i.text
        i = i.replace('\n', '')
        data[column].append(i)

df = pd.DataFrame.from_dict(data=data)[columns]
print(df.shape)
df.head()
# Out:
# (180, 3)
#   PostalCode           Borough              Neighbourhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
df = df[df['Borough'] != 'Not assigned'].reset_index(drop = True)
print('After dropping rows where borough is "Not assigned", Shape is: ',df.shape)
print('Number of rows where Neighbourhood is "Not assigned" but borough has value: ', 
      df[df['Neighbourhood'] == 'Not assigned'].shape[0])
# Out:
# After dropping rows where borough is "Not assigned", Shape is:  (103, 3)
# Number of rows where Neighbourhood is "Not assigned" but borough has value:  0

# %%
p, b, n = [], [], []
for postcode, borough, neigh in zip(df['PostalCode'], df['Borough'], df['Neighbourhood']):
    p.append(postcode)
    b.append(borough)
    if neigh == 'Not assigned':
        n.append(borough)
    else:
        n.append(neigh)

df = pd.DataFrame({'PostalCode': p, 'Borough': b, 'Neighbourhood':n})[columns]
print(df.shape)
df.head()
# Out:
# (103, 3)
#   PostalCode           Borough                                Neighbourhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
postcodes = df['PostalCode'].values
boroughs = df['Borough'].values
neighs = df['Neighbourhood'].values

# %%
dic = dict({(key1,key2): [] 
            for key1, key2 in zip(postcodes, boroughs)})
print('Number of keys in the dictionary are: ', len(dic.keys()))
# Out:
# Number of keys in the dictionary are:  103

# %%
for postcode, borough, neigh in zip(postcodes,boroughs, neighs):
    key = (postcode, borough)
    dic[key].append(neigh)

# %%
df = pd.DataFrame(columns = ['Postal Code', 'Borough', 'Neighbourhood'])
for key, value in dic.items():
    postcode, borough, neig = key[0], key[1], value
    neig = ', '.join(neig)
    df = df.append({'Postal Code': postcode,
                     'Borough': borough,
                     'Neighbourhood': neig}, ignore_index = True)
print('Shape of final data is: ', df.shape)
df.head(10)
# Out:
# Shape of final data is:  (103, 3)
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 5         M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 6         M1B       Scarborough                               Malvern, Rouge
# 7         M3B        North York                                    Don Mills
# 8         M4B         East York              Parkview Hill, Woodbine Gardens
# 9         M5B  Downtown Toronto                     Garden District, Ryerson

# %% [markdown]
# # Adding lattitude and longitude

# %%
# download the data of latitude and longitude: link given by the authour of coursera
# !wget http://cocl.us/Geospatial_data
try:
    df['Latitude'] = lats
    df['Longitude'] = lons
except:
    latlon = pd.read_csv('Geospatial_data')
    df = pd.merge(df, latlon, how= 'inner', on = 'Postal Code')
    
print(df.shape)
df.head(10)
# Out:
# --2021-01-16 11:41:00--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.63.96.176, 169.63.96.194
# Connecting to cocl.us (cocl.us)|169.63.96.176|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2021-01-16 11:41:01--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|169.63.96.176|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2021-01-16 11:41:02--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.29.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.29.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2021-01-16 11:41:03--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2021-01-16 11:41:03--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 103.116.4.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|103.116.4.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!CElfFUr_5ty8BhsSMNc-8Mj2xPgnFkcdpQMaXVOxT5oK1TlDXEcFhRXU_GyqKdNxs32NuzLy17YWju_yitcFM2ktTAW4fFYaCEo9kcxguexF_n0lhN7vbrvG-_RgiMsI-ga5mf-Olky5m02Jm7JVWQhFBtEf57oACkzfRjGh88XfBsGMw6l5z7CJfmqokOOugya2ujoNUVXCaefN4CWEWxJmFzN1EmQ3HagMXEbdmXQ0Qqiayd6H5JW4frwvNAM_Sk9vOuM5y0Z5cAYwJjUPDNSduaALTFoLwpgrYR_hnQDmUuO2AXAcKmNM56R7_P-fQhGgU9u66B4SDU8SiXFYFuaY4p-fwG7BubgJJQ7-_buHqOh3pQd5mEE75cnHhTljOO8SnbeN3sOFxrt7D5QUMkNvCKpjp3SlKmOo5rBnCcgtx8F6Xvv06MZYMD-5AsS2M_0sV6Nvf0_xom_tC8dbfLhbqzI0mGWxtC2QhhxeeTV79U0erMK3AswTWmV2aR33S-dszAabzDzLbUf47TIsOl-TSNhMDYFVG4S0AO6MDxMZIqC74Z8AIACTtk4OqCFqBjNdYr4NXSQk-6rDszpeLcqyMkCQ5coRfHdXTdAZsYdG13uVV8KA4o_dgu-lOGHVGICEWgsZibaxf_Kw-IRlA-xkVPCTr5XgalrSIhg513pL5jkS4kNjV1wB7BoHingVyv6mkj_bF6_dd9gWrU8e3arUoWr6nDyFpUT6BV-ebfE8Nr3KFViejo7JDdZ4vJuGUjprzFxLB0jxck4UOTKVPjOfVjpQBx1D9VdXdwAwD25otX8ehm9r22Vtyq3X3zIfj8nykiz1vsso-kjQrBTVq_3L4w11ew1KiyWAuqHO3MnEcexD3SDp6p5-15t8JM4d72kfMB8GWLDk7GeXa_KPzliPSAFC_NKYI9R6xVNZH4pTqqh2FXZZw9LIP9yxFnJCq2BPUv4EM9ZviPbejbH6Wetyd5Jq5SoFfJIxmB5Q_fbbdWC2fglifSIle5GNPWmQ3yx_sobZ7WVSlpGhDTBD1_d9moVhzV2dZTMUTKd4Uwdk2ovnQCE66VK9jjhSXd2GZ5kPXymrIC9jbj9tF6Gv-AF0E5A8p0zRJMBcaPbQLGQvGnHjeBhrncHV6OTNIztNlXzKaPYgO0DS36vkGR-AB9zA6fhBJfiL_bsyLudpyzKsVA5enkAqAq_eoEyYPBcBEFJQ6XSKPhSiFcF0wqIIb5qrofhIVeaLpH8GWfVUKB-_M8l_GmSLYQaPdaxfAMOMiwWKi92Az8zO21a9r6GnWlNaGetIitp1QAtJ2xPRWOFQwTz3k5npTRIDvO61O9-jA4ICAAIqqcqRv2uP2IAvv52NUFGfdNnfmkZ98zBa7yJajK7uoHfn6jdmUzyAC4E0fyVFPHbph-D5KgZTKGTq3UH0pmxmXCCMbRzU73AHnN_dHl0i8dWnSHW2gL2Auso5a623jjwwAW6BsNU7CQ../download [following]
# --2021-01-16 11:41:04--  https://public.boxcloud.com/d/1/b1!CElfFUr_5ty8BhsSMNc-8Mj2xPgnFkcdpQMaXVOxT5oK1TlDXEcFhRXU_GyqKdNxs32NuzLy17YWju_yitcFM2ktTAW4fFYaCEo9kcxguexF_n0lhN7vbrvG-_RgiMsI-ga5mf-Olky5m02Jm7JVWQhFBtEf57oACkzfRjGh88XfBsGMw6l5z7CJfmqokOOugya2ujoNUVXCaefN4CWEWxJmFzN1EmQ3HagMXEbdmXQ0Qqiayd6H5JW4frwvNAM_Sk9vOuM5y0Z5cAYwJjUPDNSduaALTFoLwpgrYR_hnQDmUuO2AXAcKmNM56R7_P-fQhGgU9u66B4SDU8SiXFYFuaY4p-fwG7BubgJJQ7-_buHqOh3pQd5mEE75cnHhTljOO8SnbeN3sOFxrt7D5QUMkNvCKpjp3SlKmOo5rBnCcgtx8F6Xvv06MZYMD-5AsS2M_0sV6Nvf0_xom_tC8dbfLhbqzI0mGWxtC2QhhxeeTV79U0erMK3AswTWmV2aR33S-dszAabzDzLbUf47TIsOl-TSNhMDYFVG4S0AO6MDxMZIqC74Z8AIACTtk4OqCFqBjNdYr4NXSQk-6rDszpeLcqyMkCQ5coRfHdXTdAZsYdG13uVV8KA4o_dgu-lOGHVGICEWgsZibaxf_Kw-IRlA-xkVPCTr5XgalrSIhg513pL5jkS4kNjV1wB7BoHingVyv6mkj_bF6_dd9gWrU8e3arUoWr6nDyFpUT6BV-ebfE8Nr3KFViejo7JDdZ4vJuGUjprzFxLB0jxck4UOTKVPjOfVjpQBx1D9VdXdwAwD25otX8ehm9r22Vtyq3X3zIfj8nykiz1vsso-kjQrBTVq_3L4w11ew1KiyWAuqHO3MnEcexD3SDp6p5-15t8JM4d72kfMB8GWLDk7GeXa_KPzliPSAFC_NKYI9R6xVNZH4pTqqh2FXZZw9LIP9yxFnJCq2BPUv4EM9ZviPbejbH6Wetyd5Jq5SoFfJIxmB5Q_fbbdWC2fglifSIle5GNPWmQ3yx_sobZ7WVSlpGhDTBD1_d9moVhzV2dZTMUTKd4Uwdk2ovnQCE66VK9jjhSXd2GZ5kPXymrIC9jbj9tF6Gv-AF0E5A8p0zRJMBcaPbQLGQvGnHjeBhrncHV6OTNIztNlXzKaPYgO0DS36vkGR-AB9zA6fhBJfiL_bsyLudpyzKsVA5enkAqAq_eoEyYPBcBEFJQ6XSKPhSiFcF0wqIIb5qrofhIVeaLpH8GWfVUKB-_M8l_GmSLYQaPdaxfAMOMiwWKi92Az8zO21a9r6GnWlNaGetIitp1QAtJ2xPRWOFQwTz3k5npTRIDvO61O9-jA4ICAAIqqcqRv2uP2IAvv52NUFGfdNnfmkZ98zBa7yJajK7uoHfn6jdmUzyAC4E0fyVFPHbph-D5KgZTKGTq3UH0pmxmXCCMbRzU73AHnN_dHl0i8dWnSHW2gL2Auso5a623jjwwAW6BsNU7CQ../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.29.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.29.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data.1’
#
# Geospatial_data.1   100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2021-01-16 11:41:05 (35.3 MB/s) - ‘Geospatial_data.1’ saved [2891/2891]
#
# (103, 5)
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 5         M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 6         M1B       Scarborough                               Malvern, Rouge
# 7         M3B        North York                                    Don Mills
# 8         M4B         East York              Parkview Hill, Woodbine Gardens
# 9         M5B  Downtown Toronto                     Garden District, Ryerson
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494
# 5  43.667856 -79.532242
# 6  43.806686 -79.194353
# 7  43.745906 -79.352188
# 8  43.706397 -79.309937
# 9  43.657162 -79.378937
